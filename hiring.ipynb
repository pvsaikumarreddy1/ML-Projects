# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_html('https://github.com/codebasics/py/blob/master/ML/2_linear_reg_multivariate/Exercise/hiring.csv')[0]

# %%
df
# Out:
#    Unnamed: 0 experience  test_score(out of 10)  interview_score(out of 10)  \
# 0         NaN        NaN                    8.0                           9
# 1         NaN        NaN                    8.0                           6
# 2         NaN       five                    6.0                           7
# 3         NaN        two                   10.0                          10
# 4         NaN      seven                    9.0                           6
# 5         NaN      three                    7.0                          10
# 6         NaN        ten                    NaN                           7
# 7         NaN     eleven                    7.0                           8
#
#    salary($)
# 0      50000
# 1      45000
# 2      60000
# 3      65000
# 4      70000
# 5      62000
# 6      72000
# 7      80000

# %%
df=df.drop('Unnamed: 0',axis='columns')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
import word2number

# %%
from word2number import w2n

# %%
#d.experience = d.experience.apply(w2n.word_to_num)
#d
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-e811e5fd667d> in <module>
# ----> 1 df.experience = df.experience.apply(w2n.word_to_num)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\lib\site-packages\word2number\w2n.py in word_to_num(number_sentence)
#     132 def word_to_num(number_sentence):
#     133     if type(number_sentence) is not str:
# ...

# %%
df=df.replace(to_replace="two",value=2)

# %%
df.replace(to_replace="seven",value=7)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2          1                    6.0                           7      60000
# 3          2                   10.0                          10      65000
# 4          7                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df=df.replace(to_replace="three",value=3)

# %%
df=df.replace(to_replace="three",value=3)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2          1                    6.0                           7      60000
# 3          2                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5          3                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df=df.replace(to_replace="seven",value=7)

# %%
df=df.replace(to_replace="ten",value=10)

# %%
df=df.replace(to_replace="eleven",value=11)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         NaN                    8.0                           9      50000
# 1         NaN                    8.0                           6      45000
# 2         1.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
df['experience']=df['experience'].fillna(0)
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         0.0                    8.0                           9      50000
# 1         0.0                    8.0                           6      45000
# 2         1.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
df['experience']=df['experience'].astype(int)

# %%
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           1                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
df['test_score(out of 10)']=df['test_score(out of 10)'].fillna(0).astype(int)

# %%
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                      8                           9      50000
# 1           0                      8                           6      45000
# 2           1                      6                           7      60000
# 3           2                     10                          10      65000
# 4           7                      9                           6      70000
# 5           3                      7                          10      62000
# 6          10                      0                           7      72000
# 7          11                      7                           8      80000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df.drop('salary($)', axis='columns'),df.salary($))
# Out:
#   File "<ipython-input-78-1af8adae5641>", line 1
#     reg.fit(df.drop('salary($)', axis='columns'),df.salary($))
#                                                            ^
# SyntaxError: invalid syntax

# %%
aa=df.drop('salary($)', axis='columns')

# %%
df=df.rename(columns={'salary($)': 'salary'})

# %%
reg.fit(df.drop('salary', axis='columns'),df.salary)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[2,9,6]])
# Out:
# array([55563.63174254])
